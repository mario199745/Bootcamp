# %%
import pandas as pd

# %%
ls
# Out:
# kaggle_survey_2022_responses.csv  sample_data/

# %% [markdown]
# ### Encuesta de Kaggle 2022
# - Descargar el zip de datos y extraer la información del ".csv"
#
# https://www.kaggle.com/competitions/kaggle-survey-2022/data

# %%
encuesta = pd.read_csv("kaggle_survey_2022_responses.csv")
# Out:
# <ipython-input-3-831147a60310>:1: DtypeWarning: Columns (0,208,211,225,244,246,255,257,259,260,261,270,271,277,278,279) have mixed types. Specify dtype option on import or set low_memory=False.
#   encuesta = pd.read_csv("kaggle_survey_2022_responses.csv")

# %%
encuesta.iloc[0,:].reset_index()
# Out:
#                      index                                                  0
# 0    Duration (in seconds)                              Duration (in seconds)
# 1                       Q2                        What is your age (# years)?
# 2                       Q3             What is your gender? - Selected Choice
# 3                       Q4          In which country do you currently reside?
# 4                       Q5  Are you currently a student? (high school, uni...
# ..                     ...                                                ...
# 291                  Q44_8  Who/what are your favorite media sources that ...
# 292                  Q44_9  Who/what are your favorite media sources that ...
# 293                 Q44_10  Who/what are your favorite media sources that ...
# 294                 Q44_11  Who/what are your favorite media sources that ...
# 295                 Q44_12  Who/what are your favorite media sources that ...
#
# [296 rows x 2 columns]

# %%
encuesta.shape
# Out:
# (23217, 296)

# %%
df_info = (
    encuesta
    .drop(0,axis=0)
    .reset_index()
    .rename(columns={'index':'id'})
    .filter(regex='Q6_|id')

)

# %%
(
    df_info
    .melt(
        id_vars=['id'],
        value_vars=None,
        var_name='preguntas',
        value_name='respuestas')
    .dropna(subset='respuestas')
    .value_counts('respuestas',normalize=True)
    .rename("porcentaje")
    .reset_index()

)
# Out:
#                                            respuestas  porcentaje
# 0                                            Coursera    0.188176
# 1   University Courses (resulting in a university ...    0.131566
# 2                                Kaggle Learn Courses    0.128672
# 3                                               Udemy    0.118986
# 4                                               Other    0.110345
# 5                                            DataCamp    0.072445
# 6                                   LinkedIn Learning    0.053796
# 7                                                None    0.051425
# 8                                                 edX    0.047948
# 9                                             Udacity    0.042985
# 10  Cloud-certification programs (direct from AWS,...    0.035368
# 11                                            Fast.ai    0.018287

# %%
df_info.melt(id_vars=['id'],value_vars=['Q6_1',"Q6_2"],var_name='nombre_columns')
# Out:
#           id nombre_columns     value
# 0          1           Q6_1       NaN
# 1          2           Q6_1       NaN
# 2          3           Q6_1  Coursera
# 3          4           Q6_1  Coursera
# 4          5           Q6_1       NaN
# ...      ...            ...       ...
# 46427  23212           Q6_2       edX
# 46428  23213           Q6_2       NaN
# 46429  23214           Q6_2       NaN
# 46430  23215           Q6_2       NaN
# 46431  23216           Q6_2       NaN
#
# [46432 rows x 3 columns]

# %%
(
    df_info
    .melt(
        id_vars=['id'],
        value_vars=None,
        var_name='preguntas',
        value_name='respuestas')
    .dropna(subset='respuestas')
    .groupby(['respuestas'])
    .agg(nro_usuario=('id','count'))
    .reset_index()
    .sort_values('nro_usuario',ascending=False)
    .assign(porc = lambda x : x.nro_usuario/x.nro_usuario.sum())

)
# Out:
#                                            respuestas  nro_usuario      porc
# 1                                            Coursera         9364  0.188176
# 10  University Courses (resulting in a university ...         6547  0.131566
# 4                                Kaggle Learn Courses         6403  0.128672
# 9                                               Udemy         5921  0.118986
# 7                                               Other         5491  0.110345
# 2                                            DataCamp         3605  0.072445
# 5                                   LinkedIn Learning         2677  0.053796
# 6                                                None         2559  0.051425
# 11                                                edX         2386  0.047948
# 8                                             Udacity         2139  0.042985
# 0   Cloud-certification programs (direct from AWS,...         1760  0.035368
# ...

# %% [markdown]
# ### ¿Cómo tratar los datos y la variedad de problemas que encuentres en ellos?

# %%
encuesta = (
    encuesta
    .drop(0,axis=0)
    .reset_index()
    .rename(
        columns={
            'Duration (in seconds)':'duration',
            'index':'id_usuario'
            }
    )
)

# %%
encuesta.filter(regex='Q6_|id_usuario').head()
# Out:
#    id_usuario      Q6_1 Q6_2                  Q6_3      Q6_4 Q6_5     Q6_6  \
# 0           1       NaN  NaN                   NaN       NaN  NaN      NaN
# 1           2       NaN  NaN                   NaN       NaN  NaN      NaN
# 2           3  Coursera  edX                   NaN  DataCamp  NaN  Udacity
# 3           4  Coursera  NaN  Kaggle Learn Courses       NaN  NaN      NaN
# 4           5       NaN  NaN                   NaN       NaN  NaN      NaN
#
#     Q6_7               Q6_8 Q6_9  \
# 0    NaN                NaN  NaN
# 1    NaN                NaN  NaN
# 2  Udemy  LinkedIn Learning  NaN
# 3  Udemy                NaN  NaN
# 4    NaN                NaN  NaN
#
#                                                Q6_10 Q6_11  Q6_12
# 0                                                NaN   NaN  Other
# 1  University Courses (resulting in a university ...   NaN    NaN
# 2  University Courses (resulting in a university ...   NaN    NaN
# ...

# %% [markdown]
# ### ¿En qué plataformas empezaste o acabaste los cursos de ciencia de datos?

# %%
primer_metodo = (
    encuesta
    .filter(regex='Q6_|id_usuario')
    .melt(
        id_vars='id_usuario',
        value_vars=None,
        var_name='pregunta',
        value_name='respuesta')
    .dropna()
)
primer_metodo.sample(10)
# Out:
#         id_usuario pregunta                                          respuesta
# 205411       13436     Q6_9  Cloud-certification programs (direct from AWS,...
# 276507       12541    Q6_12                                              Other
# 70660        22667     Q6_3                               Kaggle Learn Courses
# 155022       11041     Q6_7                                              Udemy
# 112501       16514     Q6_5                                            Fast.ai
# 284064       20098    Q6_12                                              Other
# 238740       22768    Q6_10  University Courses (resulting in a university ...
# 206590       14615     Q6_9  Cloud-certification programs (direct from AWS,...
# 240826         857    Q6_11                                               None
# 278747       14781    Q6_12                                              Other

# %%
(
    primer_metodo
    .value_counts('respuesta',normalize=True)
    .rename("nro_usuarios")
    .reset_index()
)
# Out:
#                                             respuesta  nro_usuarios
# 0                                            Coursera      0.188487
# 1   University Courses (resulting in a university ...      0.131760
# 2                                Kaggle Learn Courses      0.128807
# 3                                               Udemy      0.118857
# 4                                               Other      0.110170
# 5                                            DataCamp      0.072255
# 6                                   LinkedIn Learning      0.053754
# 7                                                None      0.051363
# 8                                                 edX      0.048079
# 9                                             Udacity      0.042735
# 10  Cloud-certification programs (direct from AWS,...      0.035389
# 11                                            Fast.ai      0.018345

# %% [markdown]
# ### ¿Otro método para realizar el mismo análisis?

# %%
analisis_agregado = (
    primer_metodo
    .groupby(['respuesta'])
    .agg(nro_usuarios=('id_usuario','count'))
    .reset_index()
    .sort_values('nro_usuarios',ascending=False)
    .assign(
        porc = lambda x: x.nro_usuarios/x.nro_usuarios.sum()
      )
)
analisis_agregado
# Out:
#                                             respuesta  nro_usuarios      porc
# 1                                            Coursera          9699  0.188487
# 10  University Courses (resulting in a university ...          6780  0.131760
# 4                                Kaggle Learn Courses          6628  0.128807
# 9                                               Udemy          6116  0.118857
# 7                                               Other          5669  0.110170
# 2                                            DataCamp          3718  0.072255
# 5                                   LinkedIn Learning          2766  0.053754
# 6                                                None          2643  0.051363
# 11                                                edX          2474  0.048079
# 8                                             Udacity          2199  0.042735
# 0   Cloud-certification programs (direct from AWS,...          1821  0.035389
# ...

# %% [markdown]
# ### ¿Puedo darle formato a los decimales?

# %%
(
    analisis_agregado
    .assign(
        porc = lambda col: col.porc
                  .apply(
                      lambda x: "{0:.2f}%".format(x*100)
                      )
    )
)
# Out:
#                                             respuesta  nro_usuarios    porc
# 1                                            Coursera          9699  18.85%
# 10  University Courses (resulting in a university ...          6780  13.18%
# 4                                Kaggle Learn Courses          6628  12.88%
# 9                                               Udemy          6116  11.89%
# 7                                               Other          5669  11.02%
# 2                                            DataCamp          3718   7.23%
# 5                                   LinkedIn Learning          2766   5.38%
# 6                                                None          2643   5.14%
# 11                                                edX          2474   4.81%
# 8                                             Udacity          2199   4.27%
# 0   Cloud-certification programs (direct from AWS,...          1821   3.54%
# ...
